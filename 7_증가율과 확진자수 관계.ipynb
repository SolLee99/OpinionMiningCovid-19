# %%
from os import listdir
from os.path import isfile, join
import json
from pandas import Series, DataFrame
import pandas as pd

new_df = pd.DataFrame()

#file open_learning data file 
df = pd.read_csv('correlation_result_data.csv', encoding='utf-8')
df
# Out:
#      Unnamed: 0        date  ftof_meeting ftof_meeting_rate  prevention  \
# 0             1  2019-11-22          -509               NaN        -797
# 1             2  2019-11-23          -633              -24%        -657
# 2             3  2019-11-24          -101               84%        -798
# 3             4  2019-11-25          -338             -235%        -668
# 4             5  2019-11-26          -493              -46%        -609
# ..          ...         ...           ...               ...         ...
# 372         373  2020-11-28          -333              -65%        -644
# 373         374  2020-11-29          -293               12%        -755
# 374         375  2020-11-30          -167               43%       -1012
# 375         376  2020-12-01          -171               -2%        -792
# 376         377  2020-12-02          -278              -63%        -743
#
#     prevention_rate  regulation regulation_rate  covid_num
# ...

# %%
df[['ftof_meeting', 'ftof_meeting_rate', 'covid_num']]
# Out:
#      ftof_meeting ftof_meeting_rate  covid_num
# 0            -509               NaN          0
# 1            -633              -24%          0
# 2            -101               84%          0
# 3            -338             -235%          0
# 4            -493              -46%          0
# ..            ...               ...        ...
# 372          -333              -65%        488
# 373          -293               12%        449
# 374          -167               43%        377
# 375          -171               -2%        451
# 376          -278              -63%        511
#
# [377 rows x 3 columns]

# %%
a = df['ftof_meeting_rate'].tolist()
a
# Out:
# [nan,
#  '-24%',
#  '84%',
#  '-235%',
#  '-46%',
#  '33%',
#  '-54%',
#  '34%',
#  '65%',
#  '-99%',
#  '-223%',
#  '42%',
#  '5%',
#  '11%',
#  '58%',
#  '-13%',
#  '-98%',
#  '-14%',
#  '25%',
#  '-59%',
#  '72%',
#  '-172%',
#  '-35%',
#  '-25%',
#  '18%',
#  '36%',
#  '67%',
#  '-85%',
#  '29%',
#  '24%',
#  '-62%',
#  '38%',
#  '-58%',
#  '10%',
#  '53%',
#  '-139%',
#  '-424%',
#  '-11%',
#  '84%',
#  '7%',
#  '-109%',
#  '-15%',
#  '18%',
#  '69%',
#  '-213%',
#  '55%',
#  '-58%',
#  '20%',
#  '57%',
#  '-367%',
#  '19%',
#  '-26%',
#  '-14%',
#  '97%',
#  '-2136%',
#  '34%',
#  '-34%',
#  '-79%',
#  '7%',
#  '-4%',
#  '-27%',
#  '71%',
#  '-80%',
#  '26%',
#  '-3%',
#  '-57%',
#  '23%',
#  '-17%',
#  '-40%',
#  '8%',
#  '-22%',
#  '-20%',
#  '-19%',
#  '94%',
#  '-411%',
#  '14%',
#  '-29%',
#  '-3%',
#  '-1%',
#  '28%',
#  '-80%',
#  '38%',
#  '-44%',
#  '-5%',
#  '22%',
#  '-30%',
#  '-2%',
#  '-19%',
#  '-3%',
#  '-41%',
#  '-15%',
#  '-56%',
#  '22%',
#  '-14%',
# ...
